# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

my_array = np.array([[1, 2, 3],
                    [4, 5, 6]])
print("Numpy validation:\n ", my_array);

my_data_set = pd.read_csv("C:/Users/David/OneDrive - Grand Canyon University/DSC540/DataSets/realestate.csv");
print("Pandas validation:\n", my_data_set.head());

plt.plot(my_array)
plt.title('Matplotlib validation')
plt.show();

y = pd.DataFrame(my_data_set[['MEDV']])
X = pd.DataFrame(my_data_set[['CRIM',
                              'TAX']])
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.25)

X_train_scaled = preprocessing.scale(X_train)
print("SciKit validation:\n", X_train_scaled[:5:2]);
# Out:
# Numpy validation:
#   [[1 2 3]
#  [4 5 6]]
# Pandas validation:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# SciKit validation:
#  [[-0.43291383 -0.70556798]
#  [-0.45542285 -0.9751834 ]
#  [-0.43467434 -0.0824568 ]]
